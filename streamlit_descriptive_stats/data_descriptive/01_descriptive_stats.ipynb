# %% [markdown]
# To Do:
#
# Model of death

# %% [markdown]
# # Descriptive stats for South West hospitals

# %%
import pandas as pd

# %%
sw = pd.read_csv('stroke_teams.csv', index_col=False)

# %%
# List of stroke teams
sw = list(sw.squeeze().values)

# %%
# Read in the data
data_all = pd.read_csv('~/ssnap_data/clean_samuel_ssnap_extract_v2.csv')

key_results = pd.DataFrame()

# %%
years_covered = sorted(list(set(data_all['year'])))
all_years_str = f'{years_covered[0]} to {years_covered[-1]}'

# %%
# # Limit data to years 2021 to 2021
# data_all = data_all[(data_all['year'] >= 2021)
#                     & (data_all['year'] <= 2021)]

# Limit data to out of hopsital onset arriving by ambulance only
# data_all = data_all[data_all['onset_to_arrival_time'] > 0]
# ^ can't limit by this as the new cleaned data (2nd Oct 2023)
# has no onset to arrival time given whenever onset known is 0.
data_all = data_all[data_all['arrive_by_ambulance'] == True]

# Add new fields
data_all['count'] = 1
data_all['prestroke_mrs_0-2'] = data_all['prior_disability'] <= 2
data_all['mrs_5-6'] = data_all['discharge_disability'] >= 5
data_all['mrs_0-2'] = data_all['discharge_disability'] <= 2

# %% [markdown]
# Restrict fields

# %%
required_fields: list = [
    'count', 'stroke_team', 'age', 'male', 'infarction', 'stroke_severity',
    'onset_to_arrival_time', 'onset_known', 'precise_onset_known',
    'onset_during_sleep', 'arrive_by_ambulance', 'year',
    'afib_anticoagulant', 'prior_disability', 'prestroke_mrs_0-2',
    'arrival_to_scan_time', 'thrombolysis',
    'scan_to_thrombolysis_time', 'death', 'discharge_disability', 'mrs_5-6', 'mrs_0-2'
]

data_all = data_all[required_fields]
mask = (
    (data_all['onset_known'] == True) & 
    (data_all['onset_to_arrival_time'] <= 240)
)
data_all['arrive_in_4_hours'] = mask

# Add change in disability
data_all['increased_disability_due_to_stroke'] = data_all['discharge_disability'] - data_all['prior_disability']

# %%
summary_stats_dict = {
    'count': 'sum',
    'stroke_team': 'none',
    'age': 'mean',
    'male': 'mean',
    'infarction': 'mean',
    'stroke_severity': 'mean',
    'onset_to_arrival_time': 'median',
    'onset_known': 'mean',
    'arrive_in_4_hours': 'mean',
    'precise_onset_known': 'mean',
    'onset_during_sleep': 'mean',
    'year': 'none',
    'afib_anticoagulant': 'mean',
    'prior_disability': 'mean',
    'prestroke_mrs_0-2': 'mean',
    'arrival_to_scan_time':     'median',
    'thrombolysis':     'mean',
    'scan_to_thrombolysis_time': 'median',
    'death': 'mean',
    'discharge_disability': 'mean',
    'increased_disability_due_to_stroke': 'mean',
    'mrs_5-6': 'mean',
    'mrs_0-2': 'mean'
}

# %% [markdown]
# ## Group stroke teams by region
#
# Import a dataframe that contains a list of the stroke team names and useful location information such as their longitude and latitude and which regions they are in. Most of the column names are Office for National Statistics labels.

# %%
df_stroke_team = pd.read_csv(
    './hospitals_and_lsoas_descriptive_stats.csv',
    index_col=False
    )

# %%
df_stroke_team.head(5).T
# Out:
#                                               0  \
# Postcode                                 B152TH
# Stroke Team  Queen Elizabeth Hospital Edgbaston
# long                                  -1.936284
# lat                                   52.453272
# LSOA11CD                              E01033562
# LSOA11NM                        Birmingham 087F
# LSOA11NMW                       Birmingham 087F
# LSOA11LONG                             -1.94449
# LSOA11LAT                              52.45242
# CCG19CD                               E38000220
# CCG19NM         NHS Birmingham and Solihull CCG
# STP19CD                               E54000017
# STP19NM                 Birmingham and Solihull
# LHB20CD                                     NaN
# LHB20NM                                     NaN
# LHB20NMW                                    NaN
# LAD17CD                               E08000025
# LAD17NM                              Birmingham
# SCN17CD                               E55000008
# SCN17NM                           West Midlands
# RGN11CD                               E12000005
# RGN11NM                           West Midlands
#
#                                                  1  \
# Postcode                                    B714HJ
# Stroke Team             Sandwell District Hospital
# long                                     -1.987884
# lat                                      52.527357
# LSOA11CD                                 E01010104
# LSOA11NM                             Sandwell 017E
# LSOA11NMW                            Sandwell 017E
# LSOA11LONG                                -1.98593
# LSOA11LAT                                  52.5221
# CCG19CD                                  E38000144
# CCG19NM       NHS Sandwell and West Birmingham CCG
# STP19CD                                  E54000016
# STP19NM      The Black Country and West Birmingham
# LHB20CD                                        NaN
# LHB20NM                                        NaN
# LHB20NMW                                       NaN
# LAD17CD                                  E08000028
# LAD17NM                                   Sandwell
# SCN17CD                                  E55000008
# SCN17NM                              West Midlands
# RGN11CD                                  E12000005
# RGN11NM                              West Midlands
#
#                                                              2  \
# Postcode                                                BA13NG
# Stroke Team                         Royal United Hospital Bath
# long                                                 -2.390566
# lat                                                  51.392764
# LSOA11CD                                             E01014428
# LSOA11NM                     Bath and North East Somerset 008B
# LSOA11NMW                    Bath and North East Somerset 008B
# LSOA11LONG                                            -2.38922
# LSOA11LAT                                             51.39029
# CCG19CD                                              E38000009
# CCG19NM                   NHS Bath and North East Somerset CCG
# STP19CD                                              E54000040
# STP19NM      Bath and North East Somerset, Swindon and Wilt...
# LHB20CD                                                    NaN
# LHB20NM                                                    NaN
# LHB20NMW                                                   NaN
# LAD17CD                                              E06000022
# LAD17NM                           Bath and North East Somerset
# SCN17CD                                              E55000009
# SCN17NM                                             South West
# RGN11CD                                              E12000009
# RGN11NM                                             South West
#
#                                     3  \
# Postcode                      BA214AT
# Stroke Team  Yeovil District Hospital
# long                        -2.633907
# lat                         50.945297
# LSOA11CD                    E01029231
# LSOA11NM          South Somerset 014A
# LSOA11NMW         South Somerset 014A
# LSOA11LONG                    -2.6334
# LSOA11LAT                    50.95035
# CCG19CD                     E38000150
# CCG19NM              NHS Somerset CCG
# STP19CD                     E54000038
# STP19NM                      Somerset
# LHB20CD                           NaN
# LHB20NM                           NaN
# LHB20NMW                          NaN
# LAD17CD                     E07000189
# LAD17NM                South Somerset
# SCN17CD                     E55000009
# SCN17NM                    South West
# RGN11CD                     E12000009
# RGN11NM                    South West
#
#                                                             4
# Postcode                                               BB23HH
# Stroke Team                          Royal Blackburn Hospital
# long                                                -2.466806
# lat                                                 53.736622
# LSOA11CD                                            E01012632
# LSOA11NM                           Blackburn with Darwen 011F
# LSOA11NMW                          Blackburn with Darwen 011F
# LSOA11LONG                                           -2.45667
# LSOA11LAT                                            53.73091
# CCG19CD                                             E38000014
# CCG19NM                         NHS Blackburn with Darwen CCG
# STP19CD                                             E54000048
# STP19NM                Healthier Lancashire and South Cumbria
# LHB20CD                                                   NaN
# LHB20NM                                                   NaN
# LHB20NMW                                                  NaN
# LAD17CD                                             E06000008
# LAD17NM                                 Blackburn with Darwen
# SCN17CD                                             E55000003
# SCN17NM      Greater Manchester, Lancashire and South Cumbria
# RGN11CD                                             E12000002
# RGN11NM                                            North West

# %% [markdown]
# The following regions are contained in this file:

# %%
regions = sorted(list(set(df_stroke_team['RGN11NM'])))

regions
# Out:
# ['East Midlands',
#  'East of England',
#  'London',
#  'North East',
#  'North West',
#  'South East',
#  'South West',
#  'Wales',
#  'West Midlands',
#  'Yorkshire and The Humber']

# %% [markdown]
# Add a "region" column to the full dataset:

# %%
# Print the length and column headings of the dataframe
# as a check that the merge worked correctly.
print(len(data_all), data_all.columns)

data_all = pd.merge(data_all, df_stroke_team, left_on='stroke_team', right_on='Stroke Team')

print(len(data_all), data_all.columns)
# Out:
# 283285 Index(['count', 'stroke_team', 'age', 'male', 'infarction', 'stroke_severity',
#        'onset_to_arrival_time', 'onset_known', 'precise_onset_known',
#        'onset_during_sleep', 'arrive_by_ambulance', 'year',
#        'afib_anticoagulant', 'prior_disability', 'prestroke_mrs_0-2',
#        'arrival_to_scan_time', 'thrombolysis', 'scan_to_thrombolysis_time',
#        'death', 'discharge_disability', 'mrs_5-6', 'mrs_0-2',
#        'arrive_in_4_hours', 'increased_disability_due_to_stroke'],
#       dtype='object')
# 282302 Index(['count', 'stroke_team', 'age', 'male', 'infarction', 'stroke_severity',
#        'onset_to_arrival_time', 'onset_known', 'precise_onset_known',
#        'onset_during_sleep', 'arrive_by_ambulance', 'year',
#        'afib_anticoagulant', 'prior_disability', 'prestroke_mrs_0-2',
#        'arrival_to_scan_time', 'thrombolysis', 'scan_to_thrombolysis_time',
#        'death', 'discharge_disability', 'mrs_5-6', 'mrs_0-2',
#        'arrive_in_4_hours', 'increased_disability_due_to_stroke', 'Postcode',
#        'Stroke Team', 'long', 'lat', 'LSOA11CD', 'LSOA11NM', 'LSOA11NMW',
#        'LSOA11LONG', 'LSOA11LAT', 'CCG19CD', 'CCG19NM', 'STP19CD', 'STP19NM',
#        'LHB20CD', 'LHB20NM', 'LHB20NMW', 'LAD17CD', 'LAD17NM', 'SCN17CD',
#        'SCN17NM', 'RGN11CD', 'RGN11NM'],
#       dtype='object')

# %% [markdown]
# ## Descriptive stats for all patients
#
# All teams:

# %%
summary_stats = dict()
for year in [all_years_str] + years_covered:
    if year == all_years_str:
        data = data_all
    else:
        data = data_all[(
            (data_all['year'] == year)
            )]
    results = dict()
    for k, v in summary_stats_dict.items():
        if v == 'mean':
            results[k] = data[k].mean()
        elif v == 'median':
            results[k] = data[k].median()
        elif v == 'sum':
            results[k] = data[k].sum()
    results['stroke_team'] = 'All England & Wales'
    results['year'] = year
    summary_stats[f'All England & Wales ({year})'] = results

# %% [markdown]
# Split by region:

# %%
for region in regions:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_all[data_all['RGN11NM'] == region]
        else:
            data = data_all[(
            (data_all['RGN11NM'] == region) &
            (data_all['year'] == year)
            )]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['year'] = year
        results['stroke_team'] = f'All {region}'
        summary_stats[f'All {region} ({year})'] = results

# %% [markdown]
# Split by individual team:

# %%
for hospital in sw:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_all[data_all['stroke_team'] == hospital]
        else:
            data = data_all[(
            (data_all['stroke_team'] == hospital) &
            (data_all['year'] == year)
            )]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['stroke_team'] = hospital
        results['year'] = year
        summary_stats[f'{hospital} ({year})'] = results

# %%
summary_stats_df = pd.DataFrame(summary_stats)

# Only keep hospitals with more than 100 admissions:
mask_count = summary_stats_df.loc['count'] > 100
summary_stats_df = summary_stats_df.T[mask_count].T

# %%
key_results['onset_known'] = summary_stats_df.loc['onset_known']
key_results['arrive in 4 hours'] = summary_stats_df.loc['arrive_in_4_hours']
key_results['thrombolysis_all_arrivals'] = summary_stats_df.loc['thrombolysis']

# Round floats to 3 decimal places:
summary_stats_df = summary_stats_df.applymap(lambda x: round(x, 3) if isinstance(x, (float)) else x)

# Convert "time" rows to float:
time_rows = ['onset_to_arrival_time', 'scan_to_thrombolysis_time', 'arrival_to_scan_time']
# summary_stats_4hr_df.loc[time_rows] = 
for r in time_rows:
    summary_stats_df.loc[r] = pd.to_numeric(summary_stats_df.loc[r])

summary_stats_df
# Out:
#                                    All England & Wales (2016 to 2021)  \
# count                                                          282302
# age                                                            75.572
# male                                                            0.515
# infarction                                                      0.867
# stroke_severity                                                 8.088
# onset_to_arrival_time                                           164.0
# onset_known                                                     0.705
# arrive_in_4_hours                                               0.437
# precise_onset_known                                             0.362
# onset_during_sleep                                              0.137
# afib_anticoagulant                                              0.188
# prior_disability                                                1.159
# prestroke_mrs_0-2                                                0.78
# arrival_to_scan_time                                             42.0
# thrombolysis                                                    0.134
# scan_to_thrombolysis_time                                        30.0
# death                                                           0.168
# discharge_disability                                             2.92
# increased_disability_due_to_stroke                              1.761
# mrs_5-6                                                         0.235
# mrs_0-2                                                         0.456
# stroke_team                                       All England & Wales
# year                                                     2016 to 2021
#
#                                    All England & Wales (2016)  \
# count                                                   45807
# age                                                    75.794
# male                                                    0.505
# infarction                                              0.867
# stroke_severity                                         8.104
# onset_to_arrival_time                                   146.0
# onset_known                                             0.695
# arrive_in_4_hours                                       0.451
# precise_onset_known                                     0.366
# onset_during_sleep                                      0.134
# afib_anticoagulant                                      0.509
# prior_disability                                        1.127
# prestroke_mrs_0-2                                       0.782
# arrival_to_scan_time                                     48.0
# thrombolysis                                            0.136
# scan_to_thrombolysis_time                                30.0
# death                                                   0.176
# discharge_disability                                    2.924
# increased_disability_due_to_stroke                      1.795
# mrs_5-6                                                 0.244
# mrs_0-2                                                 0.455
# stroke_team                               All England & Wales
# year                                                     2016
#
#                                    All England & Wales (2017)  \
# count                                                   46994
# age                                                    75.858
# male                                                    0.505
# infarction                                               0.87
# stroke_severity                                         8.262
# onset_to_arrival_time                                   150.0
# onset_known                                             0.696
# arrive_in_4_hours                                       0.448
# precise_onset_known                                     0.368
# onset_during_sleep                                       0.14
# afib_anticoagulant                                      0.428
# prior_disability                                        1.147
# prestroke_mrs_0-2                                       0.781
# arrival_to_scan_time                                     43.0
# thrombolysis                                            0.137
# scan_to_thrombolysis_time                                30.0
# death                                                   0.173
# discharge_disability                                    2.915
# increased_disability_due_to_stroke                      1.767
# mrs_5-6                                                 0.241
# mrs_0-2                                                 0.456
# stroke_team                               All England & Wales
# year                                                     2017
#
#                                    All England & Wales (2018)  \
# count                                                   46011
# age                                                    75.716
# male                                                    0.515
# infarction                                              0.868
# stroke_severity                                         8.251
# onset_to_arrival_time                                   160.0
# onset_known                                             0.707
# arrive_in_4_hours                                       0.447
# precise_onset_known                                      0.37
# onset_during_sleep                                      0.137
# afib_anticoagulant                                      0.147
# prior_disability                                        1.183
# prestroke_mrs_0-2                                       0.776
# arrival_to_scan_time                                     42.0
# thrombolysis                                            0.138
# scan_to_thrombolysis_time                                29.0
# death                                                   0.169
# discharge_disability                                    2.916
# increased_disability_due_to_stroke                      1.732
# mrs_5-6                                                  0.24
# mrs_0-2                                                  0.46
# stroke_team                               All England & Wales
# year                                                     2018
#
#                                    All England & Wales (2019)  \
# count                                                   46696
# age                                                    75.807
# male                                                    0.514
# infarction                                              0.864
# stroke_severity                                         8.178
# onset_to_arrival_time                                   166.0
# onset_known                                             0.719
# arrive_in_4_hours                                       0.443
# precise_onset_known                                     0.364
# onset_during_sleep                                      0.139
# afib_anticoagulant                                      0.157
# prior_disability                                         1.19
# prestroke_mrs_0-2                                       0.773
# arrival_to_scan_time                                     40.0
# thrombolysis                                             0.14
# scan_to_thrombolysis_time                                30.0
# death                                                   0.172
# discharge_disability                                    2.934
# increased_disability_due_to_stroke                      1.744
# mrs_5-6                                                 0.236
# mrs_0-2                                                 0.458
# stroke_team                               All England & Wales
# year                                                     2019
#
#                                    All England & Wales (2020)  \
# count                                                   46771
# age                                                    75.153
# male                                                     0.52
# infarction                                              0.868
# stroke_severity                                         7.929
# onset_to_arrival_time                                   171.0
# onset_known                                             0.707
# arrive_in_4_hours                                       0.425
# precise_onset_known                                     0.357
# onset_during_sleep                                       0.14
# afib_anticoagulant                                      0.157
# prior_disability                                        1.141
# prestroke_mrs_0-2                                       0.787
# arrival_to_scan_time                                     41.0
# thrombolysis                                            0.129
# scan_to_thrombolysis_time                                32.0
# death                                                   0.159
# discharge_disability                                    2.885
# increased_disability_due_to_stroke                      1.744
# mrs_5-6                                                 0.223
# mrs_0-2                                                 0.462
# stroke_team                               All England & Wales
# year                                                     2020
#
#                                    All England & Wales (2021)  \
# count                                                   50023
# age                                                    75.138
# male                                                    0.528
# infarction                                              0.866
# stroke_severity                                         7.825
# onset_to_arrival_time                                   189.0
# onset_known                                             0.707
# arrive_in_4_hours                                       0.411
# precise_onset_known                                     0.351
# onset_during_sleep                                      0.134
# afib_anticoagulant                                      0.163
# prior_disability                                        1.162
# prestroke_mrs_0-2                                       0.782
# arrival_to_scan_time                                     40.0
# thrombolysis                                            0.125
# scan_to_thrombolysis_time                                32.0
# death                                                   0.158
# discharge_disability                                    2.945
# increased_disability_due_to_stroke                      1.783
# mrs_5-6                                                 0.228
# mrs_0-2                                                 0.448
# stroke_team                               All England & Wales
# year                                                     2021
#
#                                    All East Midlands (2016 to 2021)  \
# count                                                         20569
# age                                                           75.28
# male                                                          0.516
# infarction                                                    0.866
# stroke_severity                                                8.39
# onset_to_arrival_time                                         159.0
# onset_known                                                   0.643
# arrive_in_4_hours                                             0.413
# precise_onset_known                                           0.313
# onset_during_sleep                                            0.144
# afib_anticoagulant                                            0.174
# prior_disability                                              1.088
# prestroke_mrs_0-2                                             0.793
# arrival_to_scan_time                                           50.0
# thrombolysis                                                  0.122
# scan_to_thrombolysis_time                                      29.0
# death                                                         0.155
# discharge_disability                                          3.048
# increased_disability_due_to_stroke                             1.96
# mrs_5-6                                                       0.233
# mrs_0-2                                                         0.4
# stroke_team                                       All East Midlands
# year                                                   2016 to 2021
#
#                                    All East Midlands (2016)  \
# count                                                  2939
# age                                                  75.851
# male                                                  0.503
# infarction                                            0.865
# stroke_severity                                       8.298
# onset_to_arrival_time                                 134.0
# onset_known                                           0.616
# arrive_in_4_hours                                     0.426
# precise_onset_known                                    0.33
# onset_during_sleep                                    0.149
# afib_anticoagulant                                     0.46
# prior_disability                                      1.171
# prestroke_mrs_0-2                                      0.77
# arrival_to_scan_time                                   52.0
# thrombolysis                                           0.13
# scan_to_thrombolysis_time                              25.0
# death                                                  0.17
# discharge_disability                                  2.951
# increased_disability_due_to_stroke                    1.777
# mrs_5-6                                               0.244
# mrs_0-2                                               0.444
# stroke_team                               All East Midlands
# year                                                   2016
#
#                                    All East Midlands (2017)  ...  \
# count                                                  2878  ...
# age                                                  75.796  ...
# male                                                  0.497  ...
# infarction                                            0.881  ...
# stroke_severity                                       8.501  ...
# onset_to_arrival_time                                 146.0  ...
# onset_known                                           0.656  ...
# arrive_in_4_hours                                     0.446  ...
# precise_onset_known                                   0.329  ...
# onset_during_sleep                                    0.162  ...
# afib_anticoagulant                                    0.403  ...
# prior_disability                                      1.164  ...
# prestroke_mrs_0-2                                      0.78  ...
# arrival_to_scan_time                                   47.0  ...
# thrombolysis                                          0.131  ...
# scan_to_thrombolysis_time                              27.0  ...
# death                                                 0.169  ...
# discharge_disability                                  3.016  ...
# increased_disability_due_to_stroke                    1.855  ...
# mrs_5-6                                               0.253  ...
# mrs_0-2                                               0.436  ...
# stroke_team                               All East Midlands  ...
# year                                                   2017  ...
#
#                                    Royal Derby Hospital (2019)  \
# count                                                      677
# age                                                     75.964
# male                                                     0.517
# infarction                                               0.846
# stroke_severity                                         10.809
# onset_to_arrival_time                                    145.0
# onset_known                                              0.548
# arrive_in_4_hours                                        0.381
# precise_onset_known                                      0.458
# onset_during_sleep                                       0.161
# afib_anticoagulant                                       0.139
# prior_disability                                         1.254
# prestroke_mrs_0-2                                        0.734
# arrival_to_scan_time                                      82.0
# thrombolysis                                             0.099
# scan_to_thrombolysis_time                                 31.0
# death                                                    0.148
# discharge_disability                                     3.251
# increased_disability_due_to_stroke                         2.0
# mrs_5-6                                                  0.269
# mrs_0-2                                                  0.316
# stroke_team                               Royal Derby Hospital
# year                                                      2019
#
#                                    Royal Derby Hospital (2020)  \
# count                                                      815
# age                                                     74.831
# male                                                     0.486
# infarction                                                0.87
# stroke_severity                                           9.42
# onset_to_arrival_time                                    175.0
# onset_known                                               0.58
# arrive_in_4_hours                                        0.339
# precise_onset_known                                      0.474
# onset_during_sleep                                        0.16
# afib_anticoagulant                                        0.15
# prior_disability                                         1.102
# prestroke_mrs_0-2                                        0.775
# arrival_to_scan_time                                      98.0
# thrombolysis                                             0.094
# scan_to_thrombolysis_time                                 29.0
# death                                                     0.11
# discharge_disability                                     3.291
# increased_disability_due_to_stroke                       2.187
# mrs_5-6                                                  0.222
# mrs_0-2                                                  0.288
# stroke_team                               Royal Derby Hospital
# year                                                      2020
#
#                                    Royal Derby Hospital (2021)  \
# count                                                      896
# age                                                     74.492
# male                                                     0.554
# infarction                                               0.857
# stroke_severity                                          9.943
# onset_to_arrival_time                                    193.0
# onset_known                                              0.622
# arrive_in_4_hours                                        0.348
# precise_onset_known                                      0.517
# onset_during_sleep                                       0.154
# afib_anticoagulant                                       0.171
# prior_disability                                         0.802
# prestroke_mrs_0-2                                        0.837
# arrival_to_scan_time                                      94.0
# thrombolysis                                             0.077
# scan_to_thrombolysis_time                                 31.0
# death                                                    0.116
# discharge_disability                                     3.139
# increased_disability_due_to_stroke                       2.334
# mrs_5-6                                                  0.213
# mrs_0-2                                                  0.335
# stroke_team                               Royal Derby Hospital
# year                                                      2021
#
#                                    Queen's Medical Centre - Nottingham (2016 to 2021)  \
# count                                                                            1213
# age                                                                            73.893
# male                                                                            0.488
# infarction                                                                      0.862
# stroke_severity                                                                 9.036
# onset_to_arrival_time                                                           155.5
# onset_known                                                                     0.577
# arrive_in_4_hours                                                               0.376
# precise_onset_known                                                             0.017
# onset_during_sleep                                                              0.005
# afib_anticoagulant                                                              0.147
# prior_disability                                                                 0.42
# prestroke_mrs_0-2                                                               0.925
# arrival_to_scan_time                                                             43.0
# thrombolysis                                                                    0.158
# scan_to_thrombolysis_time                                                        28.0
# death                                                                           0.166
# discharge_disability                                                            3.007
# increased_disability_due_to_stroke                                              2.583
# mrs_5-6                                                                         0.214
# mrs_0-2                                                                         0.423
# stroke_team                                       Queen's Medical Centre - Nottingham
# year                                                                     2016 to 2021
#
#                                    Queen's Medical Centre - Nottingham (2020)  \
# count                                                                     253
# age                                                                    74.457
# male                                                                    0.482
# infarction                                                              0.897
# stroke_severity                                                         9.312
# onset_to_arrival_time                                                   147.0
# onset_known                                                             0.711
# arrive_in_4_hours                                                       0.522
# precise_onset_known                                                     0.016
# onset_during_sleep                                                      0.004
# afib_anticoagulant                                                      0.134
# prior_disability                                                        0.466
# prestroke_mrs_0-2                                                       0.917
# arrival_to_scan_time                                                     33.0
# thrombolysis                                                            0.202
# scan_to_thrombolysis_time                                                30.0
# death                                                                   0.202
# discharge_disability                                                    3.186
# increased_disability_due_to_stroke                                      2.719
# mrs_5-6                                                                 0.253
# mrs_0-2                                                                 0.395
# stroke_team                               Queen's Medical Centre - Nottingham
# year                                                                     2020
#
#                                    Queen's Medical Centre - Nottingham (2021)  \
# count                                                                     948
# age                                                                    73.919
# male                                                                    0.485
# infarction                                                              0.855
# stroke_severity                                                         8.944
# onset_to_arrival_time                                                   163.0
# onset_known                                                             0.537
# arrive_in_4_hours                                                       0.331
# precise_onset_known                                                     0.007
# onset_during_sleep                                                      0.004
# afib_anticoagulant                                                      0.152
# prior_disability                                                        0.414
# prestroke_mrs_0-2                                                       0.926
# arrival_to_scan_time                                                     48.0
# thrombolysis                                                            0.142
# scan_to_thrombolysis_time                                                28.0
# death                                                                   0.155
# discharge_disability                                                     2.94
# increased_disability_due_to_stroke                                      2.522
# mrs_5-6                                                                 0.203
# mrs_0-2                                                                 0.436
# stroke_team                               Queen's Medical Centre - Nottingham
# year                                                                     2021
#
#                                    University Hospitals Dorset Stroke Service (2016 to 2021)  \
# count                                                                             519
# age                                                                            75.679
# male                                                                            0.555
# infarction                                                                      0.877
# stroke_severity                                                                 6.728
# onset_to_arrival_time                                                           196.0
# onset_known                                                                     0.802
# arrive_in_4_hours                                                               0.472
# precise_onset_known                                                             0.277
# onset_during_sleep                                                              0.139
# afib_anticoagulant                                                              0.133
# prior_disability                                                                1.044
# prestroke_mrs_0-2                                                               0.794
# arrival_to_scan_time                                                             66.0
# thrombolysis                                                                    0.133
# scan_to_thrombolysis_time                                                        45.0
# death                                                                           0.141
# discharge_disability                                                            2.594
# increased_disability_due_to_stroke                                              1.576
# mrs_5-6                                                                          0.17
# mrs_0-2                                                                         0.545
# stroke_team                                University Hospitals Dorset Stroke Service
# year                                                                     2016 to 2021
#
#                                    University Hospitals Dorset Stroke Service (2021)  \
# count                                                                            420
# age                                                                           75.524
# male                                                                            0.54
# infarction                                                                     0.864
# stroke_severity                                                                6.693
# onset_to_arrival_time                                                          195.5
# onset_known                                                                    0.819
# arrive_in_4_hours                                                              0.476
# precise_onset_known                                                            0.252
# onset_during_sleep                                                             0.133
# afib_anticoagulant                                                             0.119
# prior_disability                                                               1.045
# prestroke_mrs_0-2                                                              0.793
# arrival_to_scan_time                                                            72.5
# thrombolysis                                                                   0.119
# scan_to_thrombolysis_time                                                       46.5
# death                                                                          0.148
# discharge_disability                                                           2.661
# increased_disability_due_to_stroke                                             1.651
# mrs_5-6                                                                        0.179
# mrs_0-2                                                                        0.526
# stroke_team                               University Hospitals Dorset Stroke Service
# year                                                                            2021
#
#                                    Grange University Hospital (2016 to 2021)  \
# count                                                                    233
# age                                                                    73.68
# male                                                                   0.528
# infarction                                                             0.807
# stroke_severity                                                        7.258
# onset_to_arrival_time                                                  260.0
# onset_known                                                            0.691
# arrive_in_4_hours                                                      0.326
# precise_onset_known                                                    0.425
# onset_during_sleep                                                     0.185
# afib_anticoagulant                                                     0.099
# prior_disability                                                       0.438
# prestroke_mrs_0-2                                                      0.957
# arrival_to_scan_time                                                    34.0
# thrombolysis                                                           0.146
# scan_to_thrombolysis_time                                               37.5
# death                                                                  0.262
# discharge_disability                                                   2.215
# increased_disability_due_to_stroke                                     1.777
# mrs_5-6                                                                0.283
# mrs_0-2                                                                0.639
# stroke_team                                       Grange University Hospital
# year                                                            2016 to 2021
#
#                                    Grange University Hospital (2021)
# count                                                            193
# age                                                           73.666
# male                                                           0.503
# infarction                                                     0.808
# stroke_severity                                                7.275
# onset_to_arrival_time                                          243.0
# onset_known                                                    0.699
# arrive_in_4_hours                                              0.347
# precise_onset_known                                             0.42
# onset_during_sleep                                             0.181
# afib_anticoagulant                                             0.098
# prior_disability                                               0.404
# prestroke_mrs_0-2                                              0.964
# arrival_to_scan_time                                            30.0
# thrombolysis                                                   0.161
# scan_to_thrombolysis_time                                       34.0
# death                                                          0.264
# discharge_disability                                           2.181
# increased_disability_due_to_stroke                             1.777
# mrs_5-6                                                         0.28
# mrs_0-2                                                        0.637
# stroke_team                               Grange University Hospital
# year                                                            2021
#
# [23 rows x 872 columns]

# %%
summary_stats_df.to_csv('summary_stats.csv')

# %% [markdown]
# ## Limit analysis to arrival in 4 hours

# %%
mask = data_all['arrive_in_4_hours'] == True
data_4hr = data_all[mask]

# %% [markdown]
# Add onset to thrombolysis

# %%
data_4hr['onset_to_thrombolysis'] = (
    data_4hr['onset_to_arrival_time'] + 
    data_4hr['arrival_to_scan_time'] + 
    data_4hr['scan_to_thrombolysis_time'])
# Out:
# /tmp/ipykernel_36922/3667336675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_4hr['onset_to_thrombolysis'] = (

# %%
# Repeat analysis for patients arriving in 4 hours
summary_stats_4hr = dict()
for year in [all_years_str] + years_covered:
    if year == all_years_str:
        data = data_4hr
    else:
        data = data_4hr[(
            (data_4hr['year'] == year)
            )]
    results = dict()
    for k, v in summary_stats_dict.items():
        if v == 'mean':
            results[k] = data[k].mean()
        elif v == 'median':
            results[k] = data[k].median()
        elif v == 'sum':
            results[k] = data[k].sum()
    results['stroke_team'] = 'All England & Wales'
    results['year'] = year
    summary_stats_4hr[f'All England & Wales ({year})'] = results

for region in regions:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_4hr[data_4hr['RGN11NM'] == region]
        else:
            data = data_4hr[(
                (data_4hr['RGN11NM'] == region) &
                (data_4hr['year'] == year)
                )]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['year'] = year
        results['stroke_team'] = f'All {region}'
        summary_stats_4hr[f'All {region} ({year})'] = results

for hospital in sw:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_4hr[data_4hr['stroke_team'] == hospital]
        else:
            data = data_4hr[(
                (data_4hr['stroke_team'] == hospital) &
                (data_4hr['year'] == year)
                )]
        # data = data_4hr[data_4hr['stroke_team'] == hospital]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['stroke_team'] = hospital
        results['year'] = year
        summary_stats_4hr[f'{hospital} ({year})'] = results

summary_stats_4hr_df = pd.DataFrame(summary_stats_4hr)

# Only keep hospitals with more than 100 admissions
# in the full data (not the 4hr data) - same mask as earlier.
summary_stats_4hr_df = summary_stats_4hr_df.T[mask_count].T

# Round floats to 3 decimal places:
summary_stats_4hr_df = summary_stats_4hr_df.applymap(lambda x: round(x, 3) if isinstance(x, (float)) else x)

# %%
# Convert "time" rows to float:
time_rows = ['onset_to_arrival_time', 'scan_to_thrombolysis_time', 'arrival_to_scan_time']
# summary_stats_4hr_df.loc[time_rows] = 
for r in time_rows:
    summary_stats_4hr_df.loc[r] = pd.to_numeric(summary_stats_4hr_df.loc[r])

# %%
summary_stats_4hr_df.to_csv('summary_stats_4hr.csv')

# %%
rows = [
    'age', 'infarction', 'precise_onset_known', 'onset_during_sleep',
    'afib_anticoagulant', 'prior_disability', 'prestroke_mrs_0-2', 
    'stroke_severity',
    'onset_to_arrival_time', 'arrival_to_scan_time', 'thrombolysis',
    'scan_to_thrombolysis_time', 'discharge_disability', 'death',
    'increased_disability_due_to_stroke', 'mrs_5-6', 'mrs_0-2'
]

for row in rows:
    key_results[row] = summary_stats_4hr_df.loc[row]

# %%
key_results = key_results.round(3).T

# %%
key_results
# Out:
#                                    All England & Wales (2016 to 2021)  \
# onset_known                                                  0.705121
# arrive in 4 hours                                            0.437028
# thrombolysis_all_arrivals                                    0.134193
# age                                                            75.118
# infarction                                                      0.849
# precise_onset_known                                             0.632
# onset_during_sleep                                              0.047
# afib_anticoagulant                                               0.19
# prior_disability                                                  1.1
# prestroke_mrs_0-2                                               0.788
# stroke_severity                                                 9.329
# onset_to_arrival_time                                           104.0
# arrival_to_scan_time                                             26.0
# thrombolysis                                                    0.299
# scan_to_thrombolysis_time                                        30.0
# discharge_disability                                            2.921
# death                                                           0.184
# increased_disability_due_to_stroke                               1.82
# mrs_5-6                                                         0.251
# mrs_0-2                                                         0.465
#
#                                    All England & Wales (2016)  \
# onset_known                                          0.694632
# arrive in 4 hours                                    0.451154
# thrombolysis_all_arrivals                            0.136049
# age                                                    75.412
# infarction                                              0.851
# precise_onset_known                                      0.63
# onset_during_sleep                                      0.045
# afib_anticoagulant                                      0.495
# prior_disability                                        1.091
# prestroke_mrs_0-2                                       0.784
# stroke_severity                                         9.396
# onset_to_arrival_time                                    97.0
# arrival_to_scan_time                                     29.0
# thrombolysis                                            0.295
# scan_to_thrombolysis_time                                30.0
# discharge_disability                                    2.948
# death                                                   0.191
# increased_disability_due_to_stroke                      1.854
# mrs_5-6                                                  0.26
# mrs_0-2                                                 0.454
#
#                                    All England & Wales (2017)  \
# onset_known                                          0.695621
# arrive in 4 hours                                    0.448142
# thrombolysis_all_arrivals                            0.137166
# age                                                    75.282
# infarction                                              0.854
# precise_onset_known                                     0.641
# onset_during_sleep                                      0.046
# afib_anticoagulant                                       0.42
# prior_disability                                        1.089
# prestroke_mrs_0-2                                       0.791
# stroke_severity                                         9.433
# onset_to_arrival_time                                   100.0
# arrival_to_scan_time                                     26.0
# thrombolysis                                              0.3
# scan_to_thrombolysis_time                                30.0
# discharge_disability                                      2.9
# death                                                   0.186
# increased_disability_due_to_stroke                      1.809
# mrs_5-6                                                 0.253
# mrs_0-2                                                 0.471
#
#                                    All England & Wales (2018)  \
# onset_known                                            0.7072
# arrive in 4 hours                                    0.446698
# thrombolysis_all_arrivals                            0.138402
# age                                                     75.28
# infarction                                              0.851
# precise_onset_known                                     0.638
# onset_during_sleep                                      0.048
# afib_anticoagulant                                      0.147
# prior_disability                                        1.128
# prestroke_mrs_0-2                                       0.782
# stroke_severity                                         9.445
# onset_to_arrival_time                                   103.0
# arrival_to_scan_time                                     26.0
# thrombolysis                                            0.303
# scan_to_thrombolysis_time                                29.0
# discharge_disability                                    2.912
# death                                                   0.183
# increased_disability_due_to_stroke                      1.784
# mrs_5-6                                                 0.254
# mrs_0-2                                                 0.466
#
#                                    All England & Wales (2019)  \
# onset_known                                          0.719462
# arrive in 4 hours                                    0.442586
# thrombolysis_all_arrivals                            0.140033
# age                                                    75.265
# infarction                                              0.846
# precise_onset_known                                     0.633
# onset_during_sleep                                      0.046
# afib_anticoagulant                                      0.156
# prior_disability                                        1.123
# prestroke_mrs_0-2                                       0.782
# stroke_severity                                         9.417
# onset_to_arrival_time                                   104.0
# arrival_to_scan_time                                     26.0
# thrombolysis                                            0.307
# scan_to_thrombolysis_time                                30.0
# discharge_disability                                    2.942
# death                                                   0.192
# increased_disability_due_to_stroke                      1.817
# mrs_5-6                                                 0.255
# mrs_0-2                                                 0.466
#
#                                    All England & Wales (2020)  \
# onset_known                                           0.70687
# arrive in 4 hours                                    0.425328
# thrombolysis_all_arrivals                            0.128755
# age                                                    74.646
# infarction                                              0.847
# precise_onset_known                                     0.626
# onset_during_sleep                                       0.05
# afib_anticoagulant                                      0.158
# prior_disability                                         1.07
# prestroke_mrs_0-2                                       0.797
# stroke_severity                                         9.201
# onset_to_arrival_time                                   105.0
# arrival_to_scan_time                                     26.0
# thrombolysis                                            0.294
# scan_to_thrombolysis_time                                32.0
# discharge_disability                                    2.885
# death                                                   0.175
# increased_disability_due_to_stroke                      1.814
# mrs_5-6                                                 0.239
# mrs_0-2                                                 0.471
#
#                                    All England & Wales (2021)  \
# onset_known                                          0.706715
# arrive in 4 hours                                    0.410511
# thrombolysis_all_arrivals                            0.125462
# age                                                    74.799
# infarction                                              0.847
# precise_onset_known                                     0.622
# onset_during_sleep                                      0.046
# afib_anticoagulant                                      0.166
# prior_disability                                        1.099
# prestroke_mrs_0-2                                       0.794
# stroke_severity                                         9.075
# onset_to_arrival_time                                   112.0
# arrival_to_scan_time                                     25.0
# thrombolysis                                            0.295
# scan_to_thrombolysis_time                                32.0
# discharge_disability                                     2.94
# death                                                   0.174
# increased_disability_due_to_stroke                      1.841
# mrs_5-6                                                 0.243
# mrs_0-2                                                 0.462
#
#                                    All East Midlands (2016 to 2021)  \
# onset_known                                                0.643201
# arrive in 4 hours                                          0.413195
# thrombolysis_all_arrivals                                  0.122126
# age                                                          74.698
# infarction                                                    0.852
# precise_onset_known                                           0.582
# onset_during_sleep                                            0.055
# afib_anticoagulant                                            0.175
# prior_disability                                              1.029
# prestroke_mrs_0-2                                               0.8
# stroke_severity                                               9.698
# onset_to_arrival_time                                         110.0
# arrival_to_scan_time                                           29.0
# thrombolysis                                                  0.285
# scan_to_thrombolysis_time                                      29.0
# discharge_disability                                          3.048
# death                                                         0.171
# increased_disability_due_to_stroke                             2.02
# mrs_5-6                                                        0.25
# mrs_0-2                                                       0.413
#
#                                    All East Midlands (2016)  \
# onset_known                                        0.615856
# arrive in 4 hours                                  0.425655
# thrombolysis_all_arrivals                          0.129636
# age                                                  75.386
# infarction                                            0.851
# precise_onset_known                                   0.621
# onset_during_sleep                                    0.034
# afib_anticoagulant                                    0.424
# prior_disability                                      1.087
# prestroke_mrs_0-2                                     0.782
# stroke_severity                                       9.719
# onset_to_arrival_time                                 100.0
# arrival_to_scan_time                                   28.0
# thrombolysis                                          0.297
# scan_to_thrombolysis_time                              25.0
# discharge_disability                                  2.975
# death                                                 0.178
# increased_disability_due_to_stroke                    1.886
# mrs_5-6                                               0.265
# mrs_0-2                                                0.44
#
#                                    All East Midlands (2017)  ...  \
# onset_known                                        0.655664  ...
# arrive in 4 hours                                  0.445796  ...
# thrombolysis_all_arrivals                          0.131341  ...
# age                                                  75.329  ...
# infarction                                            0.866  ...
# precise_onset_known                                   0.581  ...
# onset_during_sleep                                    0.062  ...
# afib_anticoagulant                                    0.419  ...
# prior_disability                                      1.089  ...
# prestroke_mrs_0-2                                     0.787  ...
# stroke_severity                                       9.803  ...
# onset_to_arrival_time                                 106.0  ...
# arrival_to_scan_time                                   28.0  ...
# thrombolysis                                          0.291  ...
# scan_to_thrombolysis_time                              27.0  ...
# discharge_disability                                  2.976  ...
# death                                                 0.184  ...
# increased_disability_due_to_stroke                    1.888  ...
# mrs_5-6                                               0.264  ...
# mrs_0-2                                               0.463  ...
#
#                                    Royal Derby Hospital (2019)  \
# onset_known                                           0.548006
# arrive in 4 hours                                     0.381093
# thrombolysis_all_arrivals                             0.098966
# age                                                     75.717
# infarction                                               0.837
# precise_onset_known                                      0.884
# onset_during_sleep                                       0.058
# afib_anticoagulant                                       0.128
# prior_disability                                         1.295
# prestroke_mrs_0-2                                        0.709
# stroke_severity                                         12.035
# onset_to_arrival_time                                    102.5
# arrival_to_scan_time                                      39.5
# thrombolysis                                             0.256
# scan_to_thrombolysis_time                                 31.5
# discharge_disability                                     3.152
# death                                                    0.163
# increased_disability_due_to_stroke                       1.864
# mrs_5-6                                                  0.287
# mrs_0-2                                                  0.353
#
#                                    Royal Derby Hospital (2020)  \
# onset_known                                           0.580368
# arrive in 4 hours                                      0.33865
# thrombolysis_all_arrivals                             0.094479
# age                                                     72.971
# infarction                                                0.83
# precise_onset_known                                      0.884
# onset_during_sleep                                       0.054
# afib_anticoagulant                                        0.17
# prior_disability                                         0.793
# prestroke_mrs_0-2                                        0.851
# stroke_severity                                          10.25
# onset_to_arrival_time                                    106.5
# arrival_to_scan_time                                      38.0
# thrombolysis                                             0.272
# scan_to_thrombolysis_time                                 29.0
# discharge_disability                                     3.051
# death                                                    0.112
# increased_disability_due_to_stroke                       2.255
# mrs_5-6                                                  0.232
# mrs_0-2                                                  0.391
#
#                                    Royal Derby Hospital (2021)  \
# onset_known                                           0.621652
# arrive in 4 hours                                     0.348214
# thrombolysis_all_arrivals                             0.077009
# age                                                     74.599
# infarction                                               0.837
# precise_onset_known                                      0.901
# onset_during_sleep                                       0.048
# afib_anticoagulant                                       0.205
# prior_disability                                         0.798
# prestroke_mrs_0-2                                         0.84
# stroke_severity                                         12.003
# onset_to_arrival_time                                    116.0
# arrival_to_scan_time                                      51.0
# thrombolysis                                             0.221
# scan_to_thrombolysis_time                                 31.0
# discharge_disability                                     3.173
# death                                                    0.141
# increased_disability_due_to_stroke                       2.375
# mrs_5-6                                                  0.256
# mrs_0-2                                                  0.353
#
#                                    Queen's Medical Centre - Nottingham (2016 to 2021)  \
# onset_known                                                                  0.577082
# arrive in 4 hours                                                            0.375927
# thrombolysis_all_arrivals                                                    0.158285
# age                                                                             73.52
# infarction                                                                      0.875
# precise_onset_known                                                             0.044
# onset_during_sleep                                                              0.004
# afib_anticoagulant                                                              0.112
# prior_disability                                                                0.513
# prestroke_mrs_0-2                                                               0.906
# stroke_severity                                                                10.511
# onset_to_arrival_time                                                           109.0
# arrival_to_scan_time                                                             30.0
# thrombolysis                                                                    0.344
# scan_to_thrombolysis_time                                                        30.0
# discharge_disability                                                            3.185
# death                                                                           0.182
# increased_disability_due_to_stroke                                               2.67
# mrs_5-6                                                                         0.241
# mrs_0-2                                                                         0.377
#
#                                    Queen's Medical Centre - Nottingham (2020)  \
# onset_known                                                          0.711462
# arrive in 4 hours                                                    0.521739
# thrombolysis_all_arrivals                                            0.201581
# age                                                                    72.955
# infarction                                                              0.909
# precise_onset_known                                                      0.03
# onset_during_sleep                                                        0.0
# afib_anticoagulant                                                      0.106
# prior_disability                                                        0.591
# prestroke_mrs_0-2                                                       0.894
# stroke_severity                                                         9.523
# onset_to_arrival_time                                                   115.5
# arrival_to_scan_time                                                     28.5
# thrombolysis                                                            0.364
# scan_to_thrombolysis_time                                                30.0
# discharge_disability                                                    3.106
# death                                                                   0.189
# increased_disability_due_to_stroke                                      2.515
# mrs_5-6                                                                 0.242
# mrs_0-2                                                                 0.417
#
#                                    Queen's Medical Centre - Nottingham (2021)  \
# onset_known                                                           0.53692
# arrive in 4 hours                                                    0.331224
# thrombolysis_all_arrivals                                            0.142405
# age                                                                    74.156
# infarction                                                              0.866
# precise_onset_known                                                     0.022
# onset_during_sleep                                                      0.006
# afib_anticoagulant                                                      0.118
# prior_disability                                                        0.497
# prestroke_mrs_0-2                                                       0.908
# stroke_severity                                                        10.908
# onset_to_arrival_time                                                   103.0
# arrival_to_scan_time                                                     32.0
# thrombolysis                                                            0.328
# scan_to_thrombolysis_time                                                31.0
# discharge_disability                                                    3.173
# death                                                                   0.175
# increased_disability_due_to_stroke                                      2.673
# mrs_5-6                                                                 0.239
# mrs_0-2                                                                 0.373
#
#                                    University Hospitals Dorset Stroke Service (2016 to 2021)  \
# onset_known                                                                  0.801541
# arrive in 4 hours                                                            0.472062
# thrombolysis_all_arrivals                                                    0.132948
# age                                                                            75.908
# infarction                                                                      0.849
# precise_onset_known                                                             0.498
# onset_during_sleep                                                              0.073
# afib_anticoagulant                                                              0.139
# prior_disability                                                                1.016
# prestroke_mrs_0-2                                                               0.792
# stroke_severity                                                                 8.273
# onset_to_arrival_time                                                           120.0
# arrival_to_scan_time                                                             17.0
# thrombolysis                                                                    0.278
# scan_to_thrombolysis_time                                                        45.0
# discharge_disability                                                            2.814
# death                                                                           0.188
# increased_disability_due_to_stroke                                              1.814
# mrs_5-6                                                                         0.233
# mrs_0-2                                                                         0.502
#
#                                    University Hospitals Dorset Stroke Service (2021)  \
# onset_known                                                                 0.819048
# arrive in 4 hours                                                            0.47619
# thrombolysis_all_arrivals                                                   0.119048
# age                                                                            75.95
# infarction                                                                     0.835
# precise_onset_known                                                             0.46
# onset_during_sleep                                                              0.08
# afib_anticoagulant                                                              0.12
# prior_disability                                                                0.99
# prestroke_mrs_0-2                                                                0.8
# stroke_severity                                                                8.285
# onset_to_arrival_time                                                          120.0
# arrival_to_scan_time                                                            20.0
# thrombolysis                                                                    0.25
# scan_to_thrombolysis_time                                                       46.5
# discharge_disability                                                           2.909
# death                                                                            0.2
# increased_disability_due_to_stroke                                             1.939
# mrs_5-6                                                                         0.25
# mrs_0-2                                                                        0.475
#
#                                    Grange University Hospital (2016 to 2021)  \
# onset_known                                                         0.690987
# arrive in 4 hours                                                    0.32618
# thrombolysis_all_arrivals                                           0.145923
# age                                                                     72.5
# infarction                                                             0.776
# precise_onset_known                                                    0.763
# onset_during_sleep                                                       0.0
# afib_anticoagulant                                                     0.053
# prior_disability                                                       0.487
# prestroke_mrs_0-2                                                      0.934
# stroke_severity                                                        9.145
# onset_to_arrival_time                                                  151.0
# arrival_to_scan_time                                                    24.0
# thrombolysis                                                           0.447
# scan_to_thrombolysis_time                                               37.5
# discharge_disability                                                    2.25
# death                                                                  0.276
# increased_disability_due_to_stroke                                     1.763
# mrs_5-6                                                                0.276
# mrs_0-2                                                                0.618
#
#                                    Grange University Hospital (2021)
# onset_known                                                 0.699482
# arrive in 4 hours                                            0.34715
# thrombolysis_all_arrivals                                   0.160622
# age                                                           72.873
# infarction                                                     0.761
# precise_onset_known                                            0.761
# onset_during_sleep                                               0.0
# afib_anticoagulant                                              0.06
# prior_disability                                               0.448
# prestroke_mrs_0-2                                               0.94
# stroke_severity                                                9.507
# onset_to_arrival_time                                          150.0
# arrival_to_scan_time                                            22.0
# thrombolysis                                                   0.463
# scan_to_thrombolysis_time                                       34.0
# discharge_disability                                           2.299
# death                                                          0.284
# increased_disability_due_to_stroke                             1.851
# mrs_5-6                                                        0.284
# mrs_0-2                                                        0.612
#
# [20 rows x 872 columns]
