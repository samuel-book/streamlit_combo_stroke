# %% [markdown]
# To Do:
#
# Model of death

# %% [markdown]
# # Descriptive stats for South West hospitals

# %%
import pandas as pd

# %%
sw = pd.read_csv('stroke_teams.csv', index_col=False)

# %%
# List of stroke teams
sw = list(sw.squeeze().values)

# %%
sw_dic = {
    'Royal Cornwall Hospital': 'SW1',
    'Royal Devon and Exeter Hospital': 'SW2',
    'North Devon District Hospital': 'SW3',
    'Torbay Hospital': 'SW4',
    'Musgrove Park Hospital': 'SW5',
    'Yeovil District Hospital': 'SW6'
}

# sw = list(sw_dic.keys())

# Read in the data
data_all = pd.read_csv('~/ssnap_data/data.csv')

key_results = pd.DataFrame()

# %%
years_covered = sorted(list(set(data_all['year'])))
all_years_str = f'{years_covered[0]} to {years_covered[-1]}'

# %%
# # Limit data to years 2021 to 2021
# data_all = data_all[(data_all['year'] >= 2021)
#                     & (data_all['year'] <= 2021)]

# Limit data to out of hopsital onset arriving by ambulance only
data_all = data_all[data_all['onset-to-arrival time'] > 0]
data_all = data_all[data_all['arrive by ambulance'] == True]

# Add new fields
data_all['count'] = 1
data_all['prestroke mrs 0-2'] = data_all['prior disability'] <= 2
data_all['mrs 5-6'] = data_all['discharge disability'] >= 5
data_all['mrs 0-2'] = data_all['discharge disability'] <= 2

# %% [markdown]
# Restrict fields

# %%
required_fields: list = [
    'count', 'stroke team', 'age', 'male', 'infarction', 'stroke severity',
    'onset-to-arrival time', 'onset known', 'precise onset known',
    'onset during sleep', 'arrive by ambulance', 'year',
    'use of AF anticoagulants', 'prior disability', 'prestroke mrs 0-2',
    'arrival-to-scan time', 'thrombolysis',
    'scan-to-thrombolysis time', 'death', 'discharge disability', 'mrs 5-6', 'mrs 0-2'
]

data_all = data_all[required_fields]
mask = (data_all['onset known'] == True) & (
    data_all['onset-to-arrival time'] <= 240)
data_all['arrive in 4  hours'] = mask

# Add change in disability
data_all['increased disability due to stroke'] = data_all['discharge disability'] - data_all['prior disability']

# %%
summary_stats_dict = {
    'count': 'sum',
    'stroke team': 'none',
    'age': 'mean',
    'male': 'mean',
    'infarction': 'mean',
    'stroke severity': 'mean',
    'onset-to-arrival time': 'median',
    'onset known': 'mean',
    'arrive in 4  hours': 'mean',
    'precise onset known': 'mean',
    'onset during sleep': 'mean',
    'year': 'none',
    'use of AF anticoagulants': 'mean',
    'prior disability': 'mean',
    'prestroke mrs 0-2': 'mean',
    'arrival-to-scan time':     'median',
    'thrombolysis':     'mean',
    'scan-to-thrombolysis time': 'median',
    'death': 'mean',
    'discharge disability': 'mean',
    'increased disability due to stroke': 'mean',
    'mrs 5-6': 'mean',
    'mrs 0-2': 'mean'
}

# %% [markdown]
# ## Group stroke teams by region
#
# Import a dataframe that contains a list of the stroke team names and useful location information such as their longitude and latitude and which regions they are in. Most of the column names are Office for National Statistics labels.

# %%
df_stroke_team = pd.read_csv(
    './hospitals_and_lsoas_descriptive_stats.csv',
    index_col=False
    )

# %%
df_stroke_team.head(5).T
# Out:
#                                               0  \
# Postcode                                 B152TH
# Stroke Team  Queen Elizabeth Hospital Edgbaston
# long                                  -1.936284
# lat                                   52.453272
# LSOA11CD                              E01033562
# LSOA11NM                        Birmingham 087F
# LSOA11NMW                       Birmingham 087F
# LSOA11LONG                             -1.94449
# LSOA11LAT                              52.45242
# CCG19CD                               E38000220
# CCG19NM         NHS Birmingham and Solihull CCG
# STP19CD                               E54000017
# STP19NM                 Birmingham and Solihull
# LHB20CD                                     NaN
# LHB20NM                                     NaN
# LHB20NMW                                    NaN
# LAD17CD                               E08000025
# LAD17NM                              Birmingham
# SCN17CD                               E55000008
# SCN17NM                           West Midlands
# RGN11CD                               E12000005
# RGN11NM                           West Midlands
#
#                                                  1  \
# Postcode                                    B714HJ
# Stroke Team             Sandwell District Hospital
# long                                     -1.987884
# lat                                      52.527357
# LSOA11CD                                 E01010104
# LSOA11NM                             Sandwell 017E
# LSOA11NMW                            Sandwell 017E
# LSOA11LONG                                -1.98593
# LSOA11LAT                                  52.5221
# CCG19CD                                  E38000144
# CCG19NM       NHS Sandwell and West Birmingham CCG
# STP19CD                                  E54000016
# STP19NM      The Black Country and West Birmingham
# LHB20CD                                        NaN
# LHB20NM                                        NaN
# LHB20NMW                                       NaN
# LAD17CD                                  E08000028
# LAD17NM                                   Sandwell
# SCN17CD                                  E55000008
# SCN17NM                              West Midlands
# RGN11CD                                  E12000005
# RGN11NM                              West Midlands
#
#                                                              2  \
# Postcode                                                BA13NG
# Stroke Team                         Royal United Hospital Bath
# long                                                 -2.390566
# lat                                                  51.392764
# LSOA11CD                                             E01014428
# LSOA11NM                     Bath and North East Somerset 008B
# LSOA11NMW                    Bath and North East Somerset 008B
# LSOA11LONG                                            -2.38922
# LSOA11LAT                                             51.39029
# CCG19CD                                              E38000009
# CCG19NM                   NHS Bath and North East Somerset CCG
# STP19CD                                              E54000040
# STP19NM      Bath and North East Somerset, Swindon and Wilt...
# LHB20CD                                                    NaN
# LHB20NM                                                    NaN
# LHB20NMW                                                   NaN
# LAD17CD                                              E06000022
# LAD17NM                           Bath and North East Somerset
# SCN17CD                                              E55000009
# SCN17NM                                             South West
# RGN11CD                                              E12000009
# RGN11NM                                             South West
#
#                                     3  \
# Postcode                      BA214AT
# Stroke Team  Yeovil District Hospital
# long                        -2.633907
# lat                         50.945297
# LSOA11CD                    E01029231
# LSOA11NM          South Somerset 014A
# LSOA11NMW         South Somerset 014A
# LSOA11LONG                    -2.6334
# LSOA11LAT                    50.95035
# CCG19CD                     E38000150
# CCG19NM              NHS Somerset CCG
# STP19CD                     E54000038
# STP19NM                      Somerset
# LHB20CD                           NaN
# LHB20NM                           NaN
# LHB20NMW                          NaN
# LAD17CD                     E07000189
# LAD17NM                South Somerset
# SCN17CD                     E55000009
# SCN17NM                    South West
# RGN11CD                     E12000009
# RGN11NM                    South West
#
#                                                             4
# Postcode                                               BB23HH
# Stroke Team                          Royal Blackburn Hospital
# long                                                -2.466806
# lat                                                 53.736622
# LSOA11CD                                            E01012632
# LSOA11NM                           Blackburn with Darwen 011F
# LSOA11NMW                          Blackburn with Darwen 011F
# LSOA11LONG                                           -2.45667
# LSOA11LAT                                            53.73091
# CCG19CD                                             E38000014
# CCG19NM                         NHS Blackburn with Darwen CCG
# STP19CD                                             E54000048
# STP19NM                Healthier Lancashire and South Cumbria
# LHB20CD                                                   NaN
# LHB20NM                                                   NaN
# LHB20NMW                                                  NaN
# LAD17CD                                             E06000008
# LAD17NM                                 Blackburn with Darwen
# SCN17CD                                             E55000003
# SCN17NM      Greater Manchester, Lancashire and South Cumbria
# RGN11CD                                             E12000002
# RGN11NM                                            North West

# %% [markdown]
# The following regions are contained in this file:

# %%
regions = sorted(list(set(df_stroke_team['RGN11NM'])))

regions
# Out:
# ['East Midlands',
#  'East of England',
#  'London',
#  'North East',
#  'North West',
#  'South East',
#  'South West',
#  'Wales',
#  'West Midlands',
#  'Yorkshire and The Humber']

# %% [markdown]
# Add a "region" column to the full dataset:

# %%
# Print the length and column headings of the dataframe
# as a check that the merge worked correctly.
print(len(data_all), data_all.columns)

data_all = pd.merge(data_all, df_stroke_team, left_on='stroke team', right_on='Stroke Team')

print(len(data_all), data_all.columns)
# Out:
# 283946 Index(['count', 'stroke team', 'age', 'male', 'infarction', 'stroke severity',
#        'onset-to-arrival time', 'onset known', 'precise onset known',
#        'onset during sleep', 'arrive by ambulance', 'year',
#        'use of AF anticoagulants', 'prior disability', 'prestroke mrs 0-2',
#        'arrival-to-scan time', 'thrombolysis', 'scan-to-thrombolysis time',
#        'death', 'discharge disability', 'mrs 5-6', 'mrs 0-2',
#        'arrive in 4  hours', 'increased disability due to stroke'],
#       dtype='object')
# 283946 Index(['count', 'stroke team', 'age', 'male', 'infarction', 'stroke severity',
#        'onset-to-arrival time', 'onset known', 'precise onset known',
#        'onset during sleep', 'arrive by ambulance', 'year',
#        'use of AF anticoagulants', 'prior disability', 'prestroke mrs 0-2',
#        'arrival-to-scan time', 'thrombolysis', 'scan-to-thrombolysis time',
#        'death', 'discharge disability', 'mrs 5-6', 'mrs 0-2',
#        'arrive in 4  hours', 'increased disability due to stroke', 'Postcode',
#        'Stroke Team', 'long', 'lat', 'LSOA11CD', 'LSOA11NM', 'LSOA11NMW',
#        'LSOA11LONG', 'LSOA11LAT', 'CCG19CD', 'CCG19NM', 'STP19CD', 'STP19NM',
#        'LHB20CD', 'LHB20NM', 'LHB20NMW', 'LAD17CD', 'LAD17NM', 'SCN17CD',
#        'SCN17NM', 'RGN11CD', 'RGN11NM'],
#       dtype='object')

# %% [markdown]
# ## Descriptive stats for all patients
#
# All teams:

# %%
summary_stats = dict()
for year in [all_years_str] + years_covered:
    if year == all_years_str:
        data = data_all
    else:
        data = data_all[(
            (data_all['year'] == year)
            )]
    results = dict()
    for k, v in summary_stats_dict.items():
        if v == 'mean':
            results[k] = data[k].mean()
        elif v == 'median':
            results[k] = data[k].median()
        elif v == 'sum':
            results[k] = data[k].sum()
    results['stroke_team'] = 'All England & Wales'
    results['year'] = year
    summary_stats[f'All England & Wales ({year})'] = results

# %% [markdown]
# Split by region:

# %%
for region in regions:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_all[data_all['RGN11NM'] == region]
        else:
            data = data_all[(
            (data_all['RGN11NM'] == region) &
            (data_all['year'] == year)
            )]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['year'] = year
        results['stroke_team'] = f'All {region}'
        summary_stats[f'All {region} ({year})'] = results

# %% [markdown]
# Split by individual team:

# %%
for hospital in sw:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_all[data_all['stroke team'] == hospital]
        else:
            data = data_all[(
            (data_all['stroke team'] == hospital) &
            (data_all['year'] == year)
            )]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['stroke_team'] = hospital
        results['year'] = year
        summary_stats[f'{hospital} ({year})'] = results

# %%
summary_stats_df = pd.DataFrame(summary_stats)
# summary_stats_df.rename(sw_dic, axis=1, inplace = True)

# Only keep hospitals with more than 100 admissions:
mask_count = summary_stats_df.loc['count'] > 100
summary_stats_df = summary_stats_df.T[mask_count].T

# %%
key_results['onset known'] = summary_stats_df.loc['onset known']
key_results['arrive in 4 hours'] = summary_stats_df.loc['arrive in 4  hours']
key_results['thrombolysis all arrivals'] = summary_stats_df.loc['thrombolysis']

# Round floats to 3 decimal places:
summary_stats_df = summary_stats_df.applymap(lambda x: round(x, 3) if isinstance(x, (float)) else x)

# Convert "time" rows to float:
time_rows = ['onset-to-arrival time', 'scan-to-thrombolysis time', 'arrival-to-scan time']
# summary_stats_4hr_df.loc[time_rows] = 
for r in time_rows:
    summary_stats_df.loc[r] = pd.to_numeric(summary_stats_df.loc[r])

summary_stats_df
# Out:
#                                    All England & Wales (2016 to 2021)  \
# count                                                          283946
# age                                                            75.571
# male                                                            0.515
# infarction                                                      0.865
# stroke severity                                                 8.086
# onset-to-arrival time                                           331.0
# onset known                                                     0.705
# arrive in 4  hours                                              0.437
# precise onset known                                             0.361
# onset during sleep                                              0.137
# use of AF anticoagulants                                        0.141
# prior disability                                                1.158
# prestroke mrs 0-2                                                0.78
# arrival-to-scan time                                             42.0
# thrombolysis                                                    0.134
# scan-to-thrombolysis time                                        30.0
# death                                                           0.168
# discharge disability                                            2.919
# increased disability due to stroke                               1.76
# mrs 5-6                                                         0.235
# mrs 0-2                                                         0.457
# stroke_team                                       All England & Wales
# year                                                     2016 to 2021
#
#                                    All England & Wales (2016)  \
# count                                                   45925
# age                                                    75.798
# male                                                    0.505
# infarction                                              0.865
# stroke severity                                         8.104
# onset-to-arrival time                                   308.0
# onset known                                             0.695
# arrive in 4  hours                                      0.451
# precise onset known                                     0.366
# onset during sleep                                      0.133
# use of AF anticoagulants                                0.103
# prior disability                                        1.128
# prestroke mrs 0-2                                       0.782
# arrival-to-scan time                                     48.0
# thrombolysis                                            0.136
# scan-to-thrombolysis time                                30.0
# death                                                   0.176
# discharge disability                                    2.926
# increased disability due to stroke                      1.796
# mrs 5-6                                                 0.245
# mrs 0-2                                                 0.454
# stroke_team                               All England & Wales
# year                                                     2016
#
#                                    All England & Wales (2017)  \
# count                                                   47145
# age                                                    75.856
# male                                                    0.505
# infarction                                              0.867
# stroke severity                                          8.26
# onset-to-arrival time                                   318.0
# onset known                                             0.695
# arrive in 4  hours                                      0.447
# precise onset known                                     0.367
# onset during sleep                                       0.14
# use of AF anticoagulants                                0.117
# prior disability                                        1.148
# prestroke mrs 0-2                                        0.78
# arrival-to-scan time                                     43.0
# thrombolysis                                            0.137
# scan-to-thrombolysis time                                30.0
# death                                                   0.173
# discharge disability                                    2.916
# increased disability due to stroke                      1.767
# mrs 5-6                                                 0.241
# mrs 0-2                                                 0.456
# stroke_team                               All England & Wales
# year                                                     2017
#
#                                    All England & Wales (2018)  \
# count                                                   46137
# age                                                    75.719
# male                                                    0.515
# infarction                                              0.866
# stroke severity                                         8.248
# onset-to-arrival time                                   316.0
# onset known                                             0.707
# arrive in 4  hours                                      0.446
# precise onset known                                     0.369
# onset during sleep                                      0.137
# use of AF anticoagulants                                0.147
# prior disability                                        1.184
# prestroke mrs 0-2                                       0.776
# arrival-to-scan time                                     42.0
# thrombolysis                                            0.138
# scan-to-thrombolysis time                                29.0
# death                                                    0.17
# discharge disability                                    2.917
# increased disability due to stroke                      1.732
# mrs 5-6                                                  0.24
# mrs 0-2                                                  0.46
# stroke_team                               All England & Wales
# year                                                     2018
#
#                                    All England & Wales (2019)  \
# count                                                   46793
# age                                                    75.803
# male                                                    0.514
# infarction                                              0.862
# stroke severity                                         8.177
# onset-to-arrival time                                   319.0
# onset known                                             0.719
# arrive in 4  hours                                      0.442
# precise onset known                                     0.363
# onset during sleep                                      0.139
# use of AF anticoagulants                                0.157
# prior disability                                         1.19
# prestroke mrs 0-2                                       0.773
# arrival-to-scan time                                     40.0
# thrombolysis                                             0.14
# scan-to-thrombolysis time                                30.0
# death                                                   0.172
# discharge disability                                    2.934
# increased disability due to stroke                      1.743
# mrs 5-6                                                 0.236
# mrs 0-2                                                 0.458
# stroke_team                               All England & Wales
# year                                                     2019
#
#                                    All England & Wales (2020)  \
# count                                                   47224
# age                                                    75.159
# male                                                     0.52
# infarction                                              0.866
# stroke severity                                         7.926
# onset-to-arrival time                                   350.0
# onset known                                             0.707
# arrive in 4  hours                                      0.425
# precise onset known                                     0.354
# onset during sleep                                      0.139
# use of AF anticoagulants                                0.157
# prior disability                                         1.14
# prestroke mrs 0-2                                       0.787
# arrival-to-scan time                                     41.0
# thrombolysis                                            0.129
# scan-to-thrombolysis time                                32.0
# death                                                   0.158
# discharge disability                                    2.881
# increased disability due to stroke                      1.741
# mrs 5-6                                                 0.222
# mrs 0-2                                                 0.463
# stroke_team                               All England & Wales
# year                                                     2020
#
#                                    All England & Wales (2021)  \
# count                                                   50722
# age                                                    75.134
# male                                                    0.528
# infarction                                              0.865
# stroke severity                                         7.827
# onset-to-arrival time                                   370.0
# onset known                                             0.708
# arrive in 4  hours                                      0.412
# precise onset known                                     0.348
# onset during sleep                                      0.133
# use of AF anticoagulants                                0.162
# prior disability                                        1.157
# prestroke mrs 0-2                                       0.784
# arrival-to-scan time                                     40.0
# thrombolysis                                            0.126
# scan-to-thrombolysis time                                32.0
# death                                                   0.158
# discharge disability                                    2.938
# increased disability due to stroke                      1.781
# mrs 5-6                                                 0.227
# mrs 0-2                                                  0.45
# stroke_team                               All England & Wales
# year                                                     2021
#
#                                    All East Midlands (2016 to 2021)  \
# count                                                         20635
# age                                                          75.266
# male                                                          0.515
# infarction                                                    0.863
# stroke severity                                               8.384
# onset-to-arrival time                                         378.0
# onset known                                                   0.642
# arrive in 4  hours                                            0.412
# precise onset known                                           0.312
# onset during sleep                                            0.144
# use of AF anticoagulants                                      0.136
# prior disability                                              1.089
# prestroke mrs 0-2                                             0.792
# arrival-to-scan time                                           50.0
# thrombolysis                                                  0.122
# scan-to-thrombolysis time                                      29.0
# death                                                         0.155
# discharge disability                                          3.047
# increased disability due to stroke                            1.959
# mrs 5-6                                                       0.233
# mrs 0-2                                                         0.4
# stroke_team                                       All East Midlands
# year                                                   2016 to 2021
#
#                                    All East Midlands (2016)  \
# count                                                  2945
# age                                                  75.834
# male                                                  0.504
# infarction                                            0.862
# stroke severity                                       8.295
# onset-to-arrival time                                 375.0
# onset known                                           0.616
# arrive in 4  hours                                    0.426
# precise onset known                                    0.33
# onset during sleep                                    0.148
# use of AF anticoagulants                              0.091
# prior disability                                      1.169
# prestroke mrs 0-2                                     0.771
# arrival-to-scan time                                   52.0
# thrombolysis                                          0.129
# scan-to-thrombolysis time                              25.0
# death                                                  0.17
# discharge disability                                  2.952
# increased disability due to stroke                     1.78
# mrs 5-6                                               0.244
# mrs 0-2                                               0.444
# stroke_team                               All East Midlands
# year                                                   2016
#
#                                    All East Midlands (2017)  ...  \
# count                                                  2892  ...
# age                                                  75.754  ...
# male                                                  0.497  ...
# infarction                                            0.877  ...
# stroke severity                                       8.478  ...
# onset-to-arrival time                                 321.0  ...
# onset known                                           0.654  ...
# arrive in 4  hours                                    0.444  ...
# precise onset known                                   0.328  ...
# onset during sleep                                    0.161  ...
# use of AF anticoagulants                              0.112  ...
# prior disability                                      1.165  ...
# prestroke mrs 0-2                                     0.779  ...
# arrival-to-scan time                                   47.0  ...
# thrombolysis                                          0.131  ...
# scan-to-thrombolysis time                              27.0  ...
# death                                                 0.168  ...
# discharge disability                                  3.012  ...
# increased disability due to stroke                     1.85  ...
# mrs 5-6                                               0.252  ...
# mrs 0-2                                               0.436  ...
# stroke_team                               All East Midlands  ...
# year                                                   2017  ...
#
#                                    Queen's Medical Centre - Nottingham (2016 to 2021)  \
# count                                                                            1222
# age                                                                            73.854
# male                                                                            0.488
# infarction                                                                      0.856
# stroke severity                                                                 9.014
# onset-to-arrival time                                                           460.0
# onset known                                                                     0.574
# arrive in 4  hours                                                              0.374
# precise onset known                                                             0.017
# onset during sleep                                                              0.005
# use of AF anticoagulants                                                        0.149
# prior disability                                                                0.417
# prestroke mrs 0-2                                                               0.926
# arrival-to-scan time                                                             43.0
# thrombolysis                                                                    0.157
# scan-to-thrombolysis time                                                        28.0
# death                                                                           0.165
# discharge disability                                                            2.995
# increased disability due to stroke                                              2.574
# mrs 5-6                                                                         0.213
# mrs 0-2                                                                         0.426
# stroke_team                                       Queen's Medical Centre - Nottingham
# year                                                                     2016 to 2021
#
#                                    Queen's Medical Centre - Nottingham (2020)  \
# count                                                                     254
# age                                                                    74.488
# male                                                                     0.48
# infarction                                                              0.894
# stroke severity                                                         9.283
# onset-to-arrival time                                                   214.0
# onset known                                                             0.709
# arrive in 4  hours                                                       0.52
# precise onset known                                                     0.016
# onset during sleep                                                      0.004
# use of AF anticoagulants                                                0.138
# prior disability                                                        0.465
# prestroke mrs 0-2                                                       0.917
# arrival-to-scan time                                                     33.0
# thrombolysis                                                            0.201
# scan-to-thrombolysis time                                                30.0
# death                                                                   0.201
# discharge disability                                                    3.173
# increased disability due to stroke                                      2.709
# mrs 5-6                                                                 0.252
# mrs 0-2                                                                 0.398
# stroke_team                               Queen's Medical Centre - Nottingham
# year                                                                     2020
#
#                                    Queen's Medical Centre - Nottingham (2021)  \
# count                                                                     956
# age                                                                     73.86
# male                                                                    0.485
# infarction                                                              0.848
# stroke severity                                                         8.924
# onset-to-arrival time                                                   561.0
# onset known                                                             0.535
# arrive in 4  hours                                                      0.329
# precise onset known                                                     0.007
# onset during sleep                                                      0.004
# use of AF anticoagulants                                                0.154
# prior disability                                                         0.41
# prestroke mrs 0-2                                                       0.927
# arrival-to-scan time                                                     48.0
# thrombolysis                                                            0.141
# scan-to-thrombolysis time                                                28.0
# death                                                                   0.155
# discharge disability                                                    2.928
# increased disability due to stroke                                      2.513
# mrs 5-6                                                                 0.202
# mrs 0-2                                                                 0.439
# stroke_team                               Queen's Medical Centre - Nottingham
# year                                                                     2021
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2016 to 2021)  \
# count                                                                             991
# age                                                                            75.356
# male                                                                            0.526
# infarction                                                                      0.902
# stroke severity                                                                 7.918
# onset-to-arrival time                                                           220.0
# onset known                                                                     0.776
# arrive in 4  hours                                                              0.523
# precise onset known                                                             0.103
# onset during sleep                                                              0.083
# use of AF anticoagulants                                                        0.108
# prior disability                                                                0.738
# prestroke mrs 0-2                                                               0.893
# arrival-to-scan time                                                             35.0
# thrombolysis                                                                    0.174
# scan-to-thrombolysis time                                                        27.0
# death                                                                           0.089
# discharge disability                                                            2.304
# increased disability due to stroke                                              1.565
# mrs 5-6                                                                         0.133
# mrs 0-2                                                                         0.629
# stroke_team                                Invicta Ward Kent and Canterbury Hospital
# year                                                                     2016 to 2021
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2020)  \
# count                                                                            362
# age                                                                           76.174
# male                                                                           0.514
# infarction                                                                     0.945
# stroke severity                                                                7.608
# onset-to-arrival time                                                          285.0
# onset known                                                                    0.749
# arrive in 4  hours                                                             0.461
# precise onset known                                                            0.039
# onset during sleep                                                              0.08
# use of AF anticoagulants                                                       0.124
# prior disability                                                               0.798
# prestroke mrs 0-2                                                              0.876
# arrival-to-scan time                                                            38.0
# thrombolysis                                                                   0.144
# scan-to-thrombolysis time                                                       27.0
# death                                                                          0.069
# discharge disability                                                            2.18
# increased disability due to stroke                                             1.375
# mrs 5-6                                                                        0.122
# mrs 0-2                                                                        0.622
# stroke_team                               Invicta Ward Kent and Canterbury Hospital
# year                                                                            2020
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2021)  \
# count                                                                            629
# age                                                                           74.885
# male                                                                           0.533
# infarction                                                                     0.878
# stroke severity                                                                8.097
# onset-to-arrival time                                                          193.0
# onset known                                                                    0.792
# arrive in 4  hours                                                             0.558
# precise onset known                                                             0.14
# onset during sleep                                                             0.084
# use of AF anticoagulants                                                       0.099
# prior disability                                                               0.703
# prestroke mrs 0-2                                                              0.903
# arrival-to-scan time                                                            34.0
# thrombolysis                                                                   0.191
# scan-to-thrombolysis time                                                       27.0
# death                                                                            0.1
# discharge disability                                                            2.37
# increased disability due to stroke                                             1.668
# mrs 5-6                                                                         0.14
# mrs 0-2                                                                        0.633
# stroke_team                               Invicta Ward Kent and Canterbury Hospital
# year                                                                            2021
#
#                                    University Hospitals Dorset Stroke Service (2016 to 2021)  \
# count                                                                             520
# age                                                                            75.712
# male                                                                            0.554
# infarction                                                                      0.875
# stroke severity                                                                  6.74
# onset-to-arrival time                                                           257.0
# onset known                                                                       0.8
# arrive in 4  hours                                                              0.471
# precise onset known                                                             0.277
# onset during sleep                                                              0.138
# use of AF anticoagulants                                                        0.133
# prior disability                                                                1.042
# prestroke mrs 0-2                                                               0.794
# arrival-to-scan time                                                             66.0
# thrombolysis                                                                    0.133
# scan-to-thrombolysis time                                                        45.0
# death                                                                           0.142
# discharge disability                                                              2.6
# increased disability due to stroke                                              1.584
# mrs 5-6                                                                         0.171
# mrs 0-2                                                                         0.544
# stroke_team                                University Hospitals Dorset Stroke Service
# year                                                                     2016 to 2021
#
#                                    University Hospitals Dorset Stroke Service (2021)  \
# count                                                                            421
# age                                                                           75.564
# male                                                                           0.539
# infarction                                                                     0.862
# stroke severity                                                                6.708
# onset-to-arrival time                                                          255.0
# onset known                                                                    0.817
# arrive in 4  hours                                                             0.475
# precise onset known                                                            0.252
# onset during sleep                                                             0.133
# use of AF anticoagulants                                                       0.119
# prior disability                                                               1.043
# prestroke mrs 0-2                                                              0.793
# arrival-to-scan time                                                            72.5
# thrombolysis                                                                   0.119
# scan-to-thrombolysis time                                                       46.5
# death                                                                           0.15
# discharge disability                                                           2.669
# increased disability due to stroke                                             1.662
# mrs 5-6                                                                        0.181
# mrs 0-2                                                                        0.525
# stroke_team                               University Hospitals Dorset Stroke Service
# year                                                                            2021
#
#                                    Grange University Hospital (2016 to 2021)  \
# count                                                                    234
# age                                                                   73.739
# male                                                                   0.526
# infarction                                                             0.803
# stroke severity                                                        7.235
# onset-to-arrival time                                                  482.5
# onset known                                                            0.688
# arrive in 4  hours                                                     0.325
# precise onset known                                                    0.423
# onset during sleep                                                     0.184
# use of AF anticoagulants                                               0.098
# prior disability                                                        0.44
# prestroke mrs 0-2                                                      0.957
# arrival-to-scan time                                                    34.0
# thrombolysis                                                           0.145
# scan-to-thrombolysis time                                               37.5
# death                                                                  0.261
# discharge disability                                                   2.209
# increased disability due to stroke                                     1.769
# mrs 5-6                                                                0.282
# mrs 0-2                                                                0.641
# stroke_team                                       Grange University Hospital
# year                                                            2016 to 2021
#
#                                    Grange University Hospital (2021)
# count                                                            194
# age                                                           73.737
# male                                                             0.5
# infarction                                                     0.804
# stroke severity                                                7.247
# onset-to-arrival time                                          488.0
# onset known                                                    0.696
# arrive in 4  hours                                             0.345
# precise onset known                                            0.418
# onset during sleep                                              0.18
# use of AF anticoagulants                                       0.098
# prior disability                                               0.407
# prestroke mrs 0-2                                              0.964
# arrival-to-scan time                                            30.0
# thrombolysis                                                    0.16
# scan-to-thrombolysis time                                       34.0
# death                                                          0.263
# discharge disability                                           2.175
# increased disability due to stroke                             1.768
# mrs 5-6                                                        0.278
# mrs 0-2                                                        0.639
# stroke_team                               Grange University Hospital
# year                                                            2021
#
# [23 rows x 875 columns]

# %%
summary_stats_df.to_csv('summary_stats.csv')

# %% [markdown]
# ## Limit analysis to arrival in 4 hours

# %%
mask = data_all['arrive in 4  hours'] == True
data_4hr = data_all[mask]

# %% [markdown]
# Add onset to thrombolysis

# %%
data_4hr['onset to thrombolysis'] = (
    data_4hr['onset-to-arrival time'] + 
    data_4hr['arrival-to-scan time'] + 
    data_4hr['scan-to-thrombolysis time'])
# Out:
# /tmp/ipykernel_15230/3194208934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_4hr['onset to thrombolysis'] = (

# %%
# Repeat analysis for patients arriving in 4 hours
summary_stats_4hr = dict()
for year in [all_years_str] + years_covered:
    if year == all_years_str:
        data = data_4hr
    else:
        data = data_4hr[(
            (data_4hr['year'] == year)
            )]
    results = dict()
    for k, v in summary_stats_dict.items():
        if v == 'mean':
            results[k] = data[k].mean()
        elif v == 'median':
            results[k] = data[k].median()
        elif v == 'sum':
            results[k] = data[k].sum()
    results['stroke_team'] = 'All England & Wales'
    results['year'] = year
    summary_stats_4hr[f'All England & Wales ({year})'] = results

for region in regions:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_4hr[data_4hr['RGN11NM'] == region]
        else:
            data = data_4hr[(
                (data_4hr['RGN11NM'] == region) &
                (data_4hr['year'] == year)
                )]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['year'] = year
        results['stroke_team'] = f'All {region}'
        summary_stats_4hr[f'All {region} ({year})'] = results

for hospital in sw:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_4hr[data_4hr['stroke team'] == hospital]
        else:
            data = data_4hr[(
                (data_4hr['stroke team'] == hospital) &
                (data_4hr['year'] == year)
                )]
        # data = data_4hr[data_4hr['stroke team'] == hospital]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['stroke_team'] = hospital
        results['year'] = year
        summary_stats_4hr[f'{hospital} ({year})'] = results

summary_stats_4hr_df = pd.DataFrame(summary_stats_4hr)

# Only keep hospitals with more than 100 admissions
# in the full data (not the 4hr data) - same mask as earlier.
summary_stats_4hr_df = summary_stats_4hr_df.T[mask_count].T

# Round floats to 3 decimal places:
summary_stats_4hr_df = summary_stats_4hr_df.applymap(lambda x: round(x, 3) if isinstance(x, (float)) else x)

# %%
# Convert "time" rows to float:
time_rows = ['onset-to-arrival time', 'scan-to-thrombolysis time', 'arrival-to-scan time']
# summary_stats_4hr_df.loc[time_rows] = 
for r in time_rows:
    summary_stats_4hr_df.loc[r] = pd.to_numeric(summary_stats_4hr_df.loc[r])

# %%
summary_stats_4hr_df.to_csv('summary_stats_4hr.csv')

# %%
rows = [
    'age', 'infarction', 'precise onset known', 'onset during sleep',
    'use of AF anticoagulants', 'prior disability', 'prestroke mrs 0-2', 
    'stroke severity',
    'onset-to-arrival time', 'arrival-to-scan time', 'thrombolysis',
    'scan-to-thrombolysis time', 'discharge disability', 'death',
    'increased disability due to stroke', 'mrs 5-6', 'mrs 0-2'
]

for row in rows:
    key_results[row] = summary_stats_4hr_df.loc[row]

# %%
key_results = key_results.round(3).T

# %%
key_results
# Out:
#                                    All England & Wales (2016 to 2021)  \
# onset known                                                  0.705057
# arrive in 4 hours                                            0.436868
# thrombolysis all arrivals                                    0.134022
# age                                                            75.125
# infarction                                                      0.849
# precise onset known                                              0.63
# onset during sleep                                              0.047
# use of AF anticoagulants                                        0.141
# prior disability                                                  1.1
# prestroke mrs 0-2                                               0.788
# stroke severity                                                 9.331
# onset-to-arrival time                                           104.0
# arrival-to-scan time                                             26.0
# thrombolysis                                                    0.299
# scan-to-thrombolysis time                                        30.0
# discharge disability                                             2.92
# death                                                           0.184
# increased disability due to stroke                              1.819
# mrs 5-6                                                         0.251
# mrs 0-2                                                         0.466
#
#                                    All England & Wales (2016)  \
# onset known                                          0.694567
# arrive in 4 hours                                    0.450822
# thrombolysis all arrivals                              0.1357
# age                                                    75.416
# infarction                                               0.85
# precise onset known                                      0.63
# onset during sleep                                      0.044
# use of AF anticoagulants                                0.105
# prior disability                                        1.093
# prestroke mrs 0-2                                       0.784
# stroke severity                                         9.397
# onset-to-arrival time                                    97.0
# arrival-to-scan time                                     29.0
# thrombolysis                                            0.295
# scan-to-thrombolysis time                                30.0
# discharge disability                                     2.95
# death                                                   0.191
# increased disability due to stroke                      1.854
# mrs 5-6                                                 0.261
# mrs 0-2                                                 0.454
#
#                                    All England & Wales (2017)  \
# onset known                                          0.694941
# arrive in 4 hours                                    0.447343
# thrombolysis all arrivals                            0.136727
# age                                                    75.288
# infarction                                              0.853
# precise onset known                                     0.641
# onset during sleep                                      0.046
# use of AF anticoagulants                                0.116
# prior disability                                         1.09
# prestroke mrs 0-2                                       0.791
# stroke severity                                          9.44
# onset-to-arrival time                                   100.0
# arrival-to-scan time                                     26.0
# thrombolysis                                              0.3
# scan-to-thrombolysis time                                30.0
# discharge disability                                    2.901
# death                                                   0.187
# increased disability due to stroke                      1.809
# mrs 5-6                                                 0.254
# mrs 0-2                                                 0.471
#
#                                    All England & Wales (2018)  \
# onset known                                          0.706786
# arrive in 4 hours                                    0.446063
# thrombolysis all arrivals                            0.138024
# age                                                    75.289
# infarction                                               0.85
# precise onset known                                     0.638
# onset during sleep                                      0.048
# use of AF anticoagulants                                0.147
# prior disability                                        1.129
# prestroke mrs 0-2                                       0.782
# stroke severity                                         9.447
# onset-to-arrival time                                   103.0
# arrival-to-scan time                                     26.0
# thrombolysis                                            0.303
# scan-to-thrombolysis time                                29.0
# discharge disability                                    2.914
# death                                                   0.184
# increased disability due to stroke                      1.784
# mrs 5-6                                                 0.254
# mrs 0-2                                                 0.466
#
#                                    All England & Wales (2019)  \
# onset known                                          0.718975
# arrive in 4 hours                                    0.442075
# thrombolysis all arrivals                            0.139743
# age                                                     75.27
# infarction                                              0.845
# precise onset known                                     0.632
# onset during sleep                                      0.046
# use of AF anticoagulants                                0.156
# prior disability                                        1.124
# prestroke mrs 0-2                                       0.782
# stroke severity                                         9.421
# onset-to-arrival time                                   104.0
# arrival-to-scan time                                     26.0
# thrombolysis                                            0.307
# scan-to-thrombolysis time                                30.0
# discharge disability                                    2.944
# death                                                   0.192
# increased disability due to stroke                      1.818
# mrs 5-6                                                 0.255
# mrs 0-2                                                 0.466
#
#                                    All England & Wales (2020)  \
# onset known                                           0.70714
# arrive in 4 hours                                    0.425335
# thrombolysis all arrivals                            0.128621
# age                                                    74.658
# infarction                                              0.847
# precise onset known                                     0.621
# onset during sleep                                       0.05
# use of AF anticoagulants                                0.158
# prior disability                                        1.068
# prestroke mrs 0-2                                       0.798
# stroke severity                                         9.202
# onset-to-arrival time                                   105.0
# arrival-to-scan time                                     26.0
# thrombolysis                                            0.293
# scan-to-thrombolysis time                                32.0
# discharge disability                                     2.88
# death                                                   0.174
# increased disability due to stroke                      1.811
# mrs 5-6                                                 0.238
# mrs 0-2                                                 0.472
#
#                                    All England & Wales (2021)  \
# onset known                                          0.707602
# arrive in 4 hours                                     0.41207
# thrombolysis all arrivals                            0.126099
# age                                                    74.815
# infarction                                              0.847
# precise onset known                                     0.615
# onset during sleep                                      0.045
# use of AF anticoagulants                                0.164
# prior disability                                        1.094
# prestroke mrs 0-2                                       0.795
# stroke severity                                         9.079
# onset-to-arrival time                                   113.0
# arrival-to-scan time                                     25.0
# thrombolysis                                            0.295
# scan-to-thrombolysis time                                32.0
# discharge disability                                    2.933
# death                                                   0.173
# increased disability due to stroke                      1.839
# mrs 5-6                                                 0.241
# mrs 0-2                                                 0.465
#
#                                    All East Midlands (2016 to 2021)  \
# onset known                                                0.642258
# arrive in 4 hours                                          0.412309
# thrombolysis all arrivals                                  0.121735
# age                                                            74.7
# infarction                                                    0.851
# precise onset known                                           0.581
# onset during sleep                                            0.055
# use of AF anticoagulants                                      0.136
# prior disability                                               1.03
# prestroke mrs 0-2                                               0.8
# stroke severity                                               9.706
# onset-to-arrival time                                         110.0
# arrival-to-scan time                                           29.0
# thrombolysis                                                  0.284
# scan-to-thrombolysis time                                      29.0
# discharge disability                                          3.049
# death                                                         0.171
# increased disability due to stroke                            2.021
# mrs 5-6                                                       0.251
# mrs 0-2                                                       0.413
#
#                                    All East Midlands (2016)  \
# onset known                                        0.616299
# arrive in 4 hours                                  0.425806
# thrombolysis all arrivals                          0.129372
# age                                                  75.359
# infarction                                            0.848
# precise onset known                                   0.621
# onset during sleep                                    0.033
# use of AF anticoagulants                              0.096
# prior disability                                      1.086
# prestroke mrs 0-2                                     0.782
# stroke severity                                       9.718
# onset-to-arrival time                                 100.0
# arrival-to-scan time                                   28.0
# thrombolysis                                          0.296
# scan-to-thrombolysis time                              25.0
# discharge disability                                  2.974
# death                                                 0.179
# increased disability due to stroke                    1.885
# mrs 5-6                                               0.266
# mrs 0-2                                                0.44
#
#                                    All East Midlands (2017)  ...  \
# onset known                                        0.653527  ...
# arrive in 4 hours                                  0.443983  ...
# thrombolysis all arrivals                          0.130705  ...
# age                                                  75.335  ...
# infarction                                            0.865  ...
# precise onset known                                   0.581  ...
# onset during sleep                                    0.062  ...
# use of AF anticoagulants                              0.113  ...
# prior disability                                       1.09  ...
# prestroke mrs 0-2                                     0.787  ...
# stroke severity                                       9.799  ...
# onset-to-arrival time                                 106.0  ...
# arrival-to-scan time                                   28.0  ...
# thrombolysis                                           0.29  ...
# scan-to-thrombolysis time                              27.0  ...
# discharge disability                                  2.976  ...
# death                                                 0.184  ...
# increased disability due to stroke                    1.887  ...
# mrs 5-6                                               0.264  ...
# mrs 0-2                                               0.463  ...
#
#                                    Queen's Medical Centre - Nottingham (2016 to 2021)  \
# onset known                                                                  0.574468
# arrive in 4 hours                                                            0.373977
# thrombolysis all arrivals                                                    0.157119
# age                                                                            73.561
# infarction                                                                      0.873
# precise onset known                                                             0.044
# onset during sleep                                                              0.004
# use of AF anticoagulants                                                        0.114
# prior disability                                                                0.512
# prestroke mrs 0-2                                                               0.906
# stroke severity                                                                10.554
# onset-to-arrival time                                                           109.0
# arrival-to-scan time                                                             30.0
# thrombolysis                                                                    0.344
# scan-to-thrombolysis time                                                        30.0
# discharge disability                                                            3.191
# death                                                                           0.184
# increased disability due to stroke                                              2.677
# mrs 5-6                                                                         0.243
# mrs 0-2                                                                         0.376
#
#                                    Queen's Medical Centre - Nottingham (2020)  \
# onset known                                                          0.708661
# arrive in 4 hours                                                    0.519685
# thrombolysis all arrivals                                            0.200787
# age                                                                    72.955
# infarction                                                              0.909
# precise onset known                                                      0.03
# onset during sleep                                                        0.0
# use of AF anticoagulants                                                0.106
# prior disability                                                        0.591
# prestroke mrs 0-2                                                       0.894
# stroke severity                                                         9.523
# onset-to-arrival time                                                   115.5
# arrival-to-scan time                                                     28.5
# thrombolysis                                                            0.364
# scan-to-thrombolysis time                                                30.0
# discharge disability                                                    3.106
# death                                                                   0.189
# increased disability due to stroke                                      2.515
# mrs 5-6                                                                 0.242
# mrs 0-2                                                                 0.417
#
#                                    Queen's Medical Centre - Nottingham (2021)  \
# onset known                                                          0.534519
# arrive in 4 hours                                                    0.329498
# thrombolysis all arrivals                                            0.141213
# age                                                                    74.214
# infarction                                                              0.863
# precise onset known                                                     0.022
# onset during sleep                                                      0.006
# use of AF anticoagulants                                                0.121
# prior disability                                                        0.495
# prestroke mrs 0-2                                                       0.908
# stroke severity                                                        10.968
# onset-to-arrival time                                                   103.0
# arrival-to-scan time                                                     32.0
# thrombolysis                                                            0.327
# scan-to-thrombolysis time                                                31.0
# discharge disability                                                    3.182
# death                                                                   0.178
# increased disability due to stroke                                      2.684
# mrs 5-6                                                                 0.241
# mrs 0-2                                                                 0.371
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2016 to 2021)  \
# onset known                                                                  0.775984
# arrive in 4 hours                                                            0.522704
# thrombolysis all arrivals                                                    0.173562
# age                                                                            75.405
# infarction                                                                      0.902
# precise onset known                                                             0.162
# onset during sleep                                                              0.039
# use of AF anticoagulants                                                        0.104
# prior disability                                                                0.683
# prestroke mrs 0-2                                                               0.905
# stroke severity                                                                 8.863
# onset-to-arrival time                                                           115.0
# arrival-to-scan time                                                             33.0
# thrombolysis                                                                    0.282
# scan-to-thrombolysis time                                                        25.0
# discharge disability                                                            2.322
# death                                                                           0.104
# increased disability due to stroke                                              1.634
# mrs 5-6                                                                         0.154
# mrs 0-2                                                                         0.641
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2020)  \
# onset known                                                                 0.748619
# arrive in 4 hours                                                           0.461326
# thrombolysis all arrivals                                                   0.143646
# age                                                                           75.494
# infarction                                                                     0.934
# precise onset known                                                            0.084
# onset during sleep                                                              0.06
# use of AF anticoagulants                                                       0.144
# prior disability                                                               0.563
# prestroke mrs 0-2                                                              0.922
# stroke severity                                                                8.611
# onset-to-arrival time                                                          115.0
# arrival-to-scan time                                                            32.0
# thrombolysis                                                                   0.263
# scan-to-thrombolysis time                                                       25.5
# discharge disability                                                           2.123
# death                                                                          0.078
# increased disability due to stroke                                             1.555
# mrs 5-6                                                                        0.138
# mrs 0-2                                                                        0.671
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2021)  \
# onset known                                                                 0.791733
# arrive in 4 hours                                                           0.558029
# thrombolysis all arrivals                                                   0.190779
# age                                                                           75.363
# infarction                                                                     0.886
# precise onset known                                                            0.199
# onset during sleep                                                             0.028
# use of AF anticoagulants                                                       0.085
# prior disability                                                               0.741
# prestroke mrs 0-2                                                              0.897
# stroke severity                                                                8.983
# onset-to-arrival time                                                          115.0
# arrival-to-scan time                                                            33.0
# thrombolysis                                                                   0.291
# scan-to-thrombolysis time                                                       25.0
# discharge disability                                                            2.41
# death                                                                          0.117
# increased disability due to stroke                                              1.67
# mrs 5-6                                                                        0.162
# mrs 0-2                                                                        0.627
#
#                                    University Hospitals Dorset Stroke Service (2016 to 2021)  \
# onset known                                                                       0.8
# arrive in 4 hours                                                            0.471154
# thrombolysis all arrivals                                                    0.132692
# age                                                                            75.908
# infarction                                                                      0.849
# precise onset known                                                             0.498
# onset during sleep                                                              0.073
# use of AF anticoagulants                                                        0.139
# prior disability                                                                1.016
# prestroke mrs 0-2                                                               0.792
# stroke severity                                                                 8.273
# onset-to-arrival time                                                           120.0
# arrival-to-scan time                                                             17.0
# thrombolysis                                                                    0.278
# scan-to-thrombolysis time                                                        45.0
# discharge disability                                                            2.814
# death                                                                           0.188
# increased disability due to stroke                                              1.814
# mrs 5-6                                                                         0.233
# mrs 0-2                                                                         0.502
#
#                                    University Hospitals Dorset Stroke Service (2021)  \
# onset known                                                                 0.817102
# arrive in 4 hours                                                           0.475059
# thrombolysis all arrivals                                                   0.118765
# age                                                                            75.95
# infarction                                                                     0.835
# precise onset known                                                             0.46
# onset during sleep                                                              0.08
# use of AF anticoagulants                                                        0.12
# prior disability                                                                0.99
# prestroke mrs 0-2                                                                0.8
# stroke severity                                                                8.285
# onset-to-arrival time                                                          120.0
# arrival-to-scan time                                                            20.0
# thrombolysis                                                                    0.25
# scan-to-thrombolysis time                                                       46.5
# discharge disability                                                           2.909
# death                                                                            0.2
# increased disability due to stroke                                             1.939
# mrs 5-6                                                                         0.25
# mrs 0-2                                                                        0.475
#
#                                    Grange University Hospital (2016 to 2021)  \
# onset known                                                         0.688034
# arrive in 4 hours                                                   0.324786
# thrombolysis all arrivals                                           0.145299
# age                                                                     72.5
# infarction                                                             0.776
# precise onset known                                                    0.763
# onset during sleep                                                       0.0
# use of AF anticoagulants                                               0.053
# prior disability                                                       0.487
# prestroke mrs 0-2                                                      0.934
# stroke severity                                                        9.145
# onset-to-arrival time                                                  151.0
# arrival-to-scan time                                                    24.0
# thrombolysis                                                           0.447
# scan-to-thrombolysis time                                               37.5
# discharge disability                                                    2.25
# death                                                                  0.276
# increased disability due to stroke                                     1.763
# mrs 5-6                                                                0.276
# mrs 0-2                                                                0.618
#
#                                    Grange University Hospital (2021)
# onset known                                                 0.695876
# arrive in 4 hours                                           0.345361
# thrombolysis all arrivals                                   0.159794
# age                                                           72.873
# infarction                                                     0.761
# precise onset known                                            0.761
# onset during sleep                                               0.0
# use of AF anticoagulants                                        0.06
# prior disability                                               0.448
# prestroke mrs 0-2                                               0.94
# stroke severity                                                9.507
# onset-to-arrival time                                          150.0
# arrival-to-scan time                                            22.0
# thrombolysis                                                   0.463
# scan-to-thrombolysis time                                       34.0
# discharge disability                                           2.299
# death                                                          0.284
# increased disability due to stroke                             1.851
# mrs 5-6                                                        0.284
# mrs 0-2                                                        0.612
#
# [20 rows x 875 columns]
